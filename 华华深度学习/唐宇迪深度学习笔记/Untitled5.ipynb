# %%
import tensorflow as tf
v1=tf.Variable(tf.random_normal([1,2]),name='v1')
v2=tf.Variable(tf.random_normal([2,3]),name='v2')
saver=tf.train.Saver()
with tf.Session() as sess:
    tf.global_variables_initializer().run()
    print("V1:",sess.run(v1))
    print("V2:",sess.run(v2))
    saver_path=saver.save(sess,'F:\\hua\\mo\\model.ckpt')
    print("Model saved in file:",saver_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-d5d7a5377fcb> in <module>()
# ----> 1 import tensorflow as tf
#       2 v1=tf.Variable(tf.random_normal([1,2]),name='v1')
#       3 v2=tf.Variable(tf.random_normal([2,3]),name='v2')
#       4 saver=tf.train.Saver()
#       5 with tf.Session() as sess:
#
# C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\__init__.py in <module>()
#      22
#      23 # pylint: disable=wildcard-import
# ---> 24 from tensorflow.python import *
#      25 # pylint: enable=wildcard-import
#      26
#
# C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>()
#      61
#      62 # Framework
# ---> 63 from tensorflow.python.framework.framework_lib import *
#      64 from tensorflow.python.framework.versions import *
#      65 from tensorflow.python.framework import errors
#
# C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\framework\framework_lib.py in <module>()
#      96 from tensorflow.python.framework.random_seed import set_random_seed
#      97 from tensorflow.python.framework.sparse_tensor import convert_to_tensor_or_sparse_tensor
# ---> 98 from tensorflow.python.framework.subscribe import subscribe
#      99 from tensorflow.python.framework.importer import import_graph_def
#     100
#
# C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\framework\subscribe.py in <module>()
#      24 from tensorflow.python.framework import ops
#      25 from tensorflow.python.ops import array_ops
# ---> 26 from tensorflow.python.ops import variables
#      27 from tensorflow.python.platform import tf_logging as logging
#      28
#
# C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in <module>()
#      24 from tensorflow.python.framework import tensor_shape
#      25 from tensorflow.python.ops import array_ops
# ---> 26 from tensorflow.python.ops import control_flow_ops
#      27 from tensorflow.python.ops import math_ops
#      28 from tensorflow.python.ops import state_ops
#
# C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in <module>()
#      65 from tensorflow.python.ops import gen_array_ops
#      66 from tensorflow.python.ops import gen_control_flow_ops
# ---> 67 from tensorflow.python.ops import gen_data_flow_ops
#      68 from tensorflow.python.ops import gen_logging_ops
#      69 from tensorflow.python.ops import math_ops
#
# C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_data_flow_ops.py in <module>()
#    5583
#    5584
# -> 5585 _op_def_lib = _InitOpDefLibrary()
#
# C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_data_flow_ops.py in _InitOpDefLibrary()
#    2850 def _InitOpDefLibrary():
#    2851   op_list = _op_def_pb2.OpList()
# -> 2852   _text_format.Merge(_InitOpDefLibrary.op_list_ascii, op_list)
#    2853   _op_def_registry.register_op_list(op_list)
#    2854   op_def_lib = _op_def_library.OpDefLibrary()
#
# C:\Users\pujing\Anaconda3\lib\site-packages\google\protobuf\text_format.py in Merge(text, message, allow_unknown_extension, allow_field_number, descriptor_pool)
#     479       allow_unknown_extension,
#     480       allow_field_number,
# --> 481       descriptor_pool=descriptor_pool)
#     482
#     483
#
# C:\Users\pujing\Anaconda3\lib\site-packages\google\protobuf\text_format.py in MergeLines(lines, message, allow_unknown_extension, allow_field_number, descriptor_pool)
#     533                    allow_field_number,
#     534                    descriptor_pool=descriptor_pool)
# --> 535   return parser.MergeLines(lines, message)
#     536
#     537
#
# C:\Users\pujing\Anaconda3\lib\site-packages\google\protobuf\text_format.py in MergeLines(self, lines, message)
#     566     """Merges a text representation of a protocol message into a message."""
#     567     self._allow_multiple_scalars = True
# --> 568     self._ParseOrMerge(lines, message)
#     569     return message
#     570
#
# C:\Users\pujing\Anaconda3\lib\site-packages\google\protobuf\text_format.py in _ParseOrMerge(self, lines, message)
#     581     tokenizer = Tokenizer(lines)
#     582     while not tokenizer.AtEnd():
# --> 583       self._MergeField(tokenizer, message)
#     584
#     585   def _MergeField(self, tokenizer, message):
#
# C:\Users\pujing\Anaconda3\lib\site-packages\google\protobuf\text_format.py in _MergeField(self, tokenizer, message)
#     682
#     683       else:
# --> 684         merger(tokenizer, message, field)
#     685
#     686     else:  # Proto field is unknown.
#
# C:\Users\pujing\Anaconda3\lib\site-packages\google\protobuf\text_format.py in _MergeMessageField(self, tokenizer, message, field)
#     771       if tokenizer.AtEnd():
#     772         raise tokenizer.ParseErrorPreviousToken('Expected "%s".' % (end_token,))
# --> 773       self._MergeField(tokenizer, sub_message)
#     774
#     775     if is_map_entry:
#
# C:\Users\pujing\Anaconda3\lib\site-packages\google\protobuf\text_format.py in _MergeField(self, tokenizer, message)
#     682
#     683       else:
# --> 684         merger(tokenizer, message, field)
#     685
#     686     else:  # Proto field is unknown.
#
# C:\Users\pujing\Anaconda3\lib\site-packages\google\protobuf\text_format.py in _MergeMessageField(self, tokenizer, message, field)
#     771       if tokenizer.AtEnd():
#     772         raise tokenizer.ParseErrorPreviousToken('Expected "%s".' % (end_token,))
# --> 773       self._MergeField(tokenizer, sub_message)
#     774
#     775     if is_map_entry:
#
# C:\Users\pujing\Anaconda3\lib\site-packages\google\protobuf\text_format.py in _MergeField(self, tokenizer, message)
#     682
#     683       else:
# --> 684         merger(tokenizer, message, field)
#     685
#     686     else:  # Proto field is unknown.
#
# C:\Users\pujing\Anaconda3\lib\site-packages\google\protobuf\text_format.py in _MergeScalarField(self, tokenizer, message, field)
#     816       value = tokenizer.ConsumeBool()
#     817     elif field.type == descriptor.FieldDescriptor.TYPE_STRING:
# --> 818       value = tokenizer.ConsumeString()
#     819     elif field.type == descriptor.FieldDescriptor.TYPE_BYTES:
#     820       value = tokenizer.ConsumeByteString()
#
# C:\Users\pujing\Anaconda3\lib\site-packages\google\protobuf\text_format.py in ConsumeString(self)
#    1174       ParseError: If a string value couldn't be consumed.
#    1175     """
# -> 1176     the_bytes = self.ConsumeByteString()
#    1177     try:
#    1178       return six.text_type(the_bytes, 'utf-8')
#
# C:\Users\pujing\Anaconda3\lib\site-packages\google\protobuf\text_format.py in ConsumeByteString(self)
#    1189       ParseError: If a byte array value couldn't be consumed.
#    1190     """
# -> 1191     the_list = [self._ConsumeSingleByteString()]
#    1192     while self.token and self.token[0] in _QUOTES:
#    1193       the_list.append(self._ConsumeSingleByteString())
#
# C:\Users\pujing\Anaconda3\lib\site-packages\google\protobuf\text_format.py in _ConsumeSingleByteString(self)
#    1217     except ValueError as e:
#    1218       raise self.ParseError(str(e))
# -> 1219     self.NextToken()
#    1220     return result
#    1221
#
# C:\Users\pujing\Anaconda3\lib\site-packages\google\protobuf\text_format.py in NextToken(self)
#    1259       return
#    1260
# -> 1261     match = self._TOKEN.match(self._current_line, self._column)
#    1262     if not match and not self._skip_comments:
#    1263       match = self._COMMENT.match(self._current_line, self._column)
#
# KeyboardInterrupt:

# %%
import tensorflow as tf
v1=tf.Variable(tf.random_normal([1,2]),name="v1")
v2=tf.Variable(tf.random_normal([2,3]),name="v2")
saver=tf.train.Saver()
with tf.Session() as sess:
    saver.restore(sess,'F:\\hua\\mo\\model.ckpt')
    print("V1:",sess.run(v1))
    print("V2:",sess.run(v2))
# Out:
# INFO:tensorflow:Restoring parameters from F:\hua\mo\model.ckpt
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#
# C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#
# C:\Users\pujing\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#      88             try:
# ---> 89                 next(self.gen)
#      90             except StopIteration:
#
# C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\framework\errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# NotFoundError: Key v1_1 not found in checkpoint
# 	 [[Node: save_10/RestoreV2_1 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_10/Const_0, save_10/RestoreV2_1/tensor_names, save_10/RestoreV2_1/shape_and_slices)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-12-f66a8afd0231> in <module>()
#       4 saver=tf.train.Saver()
#       5 with tf.Session() as sess:
# ----> 6     saver.restore(sess,'F:\\hua\\mo\\model.ckpt')
#       7     print("V1:",sess.run(v1))
#       8     print("V2:",sess.run(v2))
#
# C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1455     logging.info("Restoring parameters from %s", save_path)
#    1456     sess.run(self.saver_def.restore_op_name,
# -> 1457              {self.saver_def.filename_tensor_name: save_path})
#    1458
#    1459   @staticmethod
#
# C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1050         except KeyError:
#    1051           pass
# -> 1052       raise type(e)(node_def, op, message)
#    1053
#    1054   def _extend_graph(self):
#
# NotFoundError: Key v1_1 not found in checkpoint
# 	 [[Node: save_10/RestoreV2_1 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_10/Const_0, save_10/RestoreV2_1/tensor_names, save_10/RestoreV2_1/shape_and_slices)]]
#
# Caused by op 'save_10/RestoreV2_1', defined at:
#   File "C:\Users\pujing\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\pujing\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\ipykernel\__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\tornado\ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\tornado\stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\tornado\stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-f66a8afd0231>", line 4, in <module>
#     saver=tf.train.Saver()
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 1056, in __init__
#     self.build()
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 1086, in build
#     restore_sequentially=self._restore_sequentially)
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 691, in build
#     restore_sequentially, reshape)
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 407, in _AddRestoreOps
#     tensors = self.restore_op(filename_tensor, saveable, preferred_shard)
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 247, in restore_op
#     [spec.tensor.dtype])[0])
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_io_ops.py", line 669, in restore_v2
#     dtypes=dtypes, name=name)
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 768, in apply_op
#     op_def=op_def)
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 2336, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "C:\Users\pujing\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1228, in __init__
#     self._traceback = _extract_stack()
#
# NotFoundError (see above for traceback): Key v1_1 not found in checkpoint
# 	 [[Node: save_10/RestoreV2_1 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_10/Const_0, save_10/RestoreV2_1/tensor_names, save_10/RestoreV2_1/shape_and_slices)]]
